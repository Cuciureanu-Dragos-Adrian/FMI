# %% [markdown]
# ### Imports

# %%
! pip install unidecode
! pip install transformers
! pip install torch
! pip install spacy
! pip install pandas
! pip install gensim
! pip install xgboost
! pip install gensim
! pip install scikit-learn
! pip install unidecode
! pip install torch.utils.data
! pip install seaborn
! pip install matplotlib

import pandas as pd
import re
import spacy
import string
import numpy as np
import nltk
import torch
import sklearn
import matplotlib.pyplot as plt
import seaborn
from gensim.models import Word2Vec
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from unidecode import unidecode
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import RidgeClassifier
from torch.utils.data import DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
# Out:
# Requirement already satisfied: unidecode in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.3.6)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.27.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (1.24.2)
# Requirement already satisfied: requests in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (0.13.4)
# Requirement already satisfied: filelock in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: colorama in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers) (1.26.14)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.0.0)
# Requirement already satisfied: networkx in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.1)
# Requirement already satisfied: filelock in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.11.0)
# Requirement already satisfied: sympy in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (2.28.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (8.1.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (1.24.2)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (1.1.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (23.0)
# Requirement already satisfied: jinja2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (1.10.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: colorama in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->spacy) (2.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: gensim in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.3.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.24.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (6.3.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.7.5)
# Requirement already satisfied: scipy in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from xgboost) (1.10.1)
# Requirement already satisfied: numpy in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from xgboost) (1.24.2)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: gensim in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.3.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.24.2)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.24.2)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: unidecode in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.3.6)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement torch.utils.data (from versions: none)
# ERROR: No matching distribution found for torch.utils.data
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\gruia\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\gruia\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nlp = spacy.load('en_core_web_sm')
stemmer = SnowballStemmer('english')
STOP_WORDS = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gruia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gruia\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gruia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Dataset

# %%
df = pd.read_csv('sample_data/racism-dataset.csv', sep=',', index_col=0)
df.head(10)
# Out:
#     label                                               text
# 1       0   @user when a father is dysfunctional and is s...
# 2       0  @user @user thanks for #lyft credit i can't us...
# 3       0                                bihday your majesty
# 4       0  #model   i love u take with u all the time in ...
# 5       0             factsguide: society now    #motivation
# 6       0  [2/2] huge fan fare and big talking before the...
# 7       0   @user camping tomorrow @user @user @user @use...
# 8       0  the next school year is the year for exams.ð...
# 9       0  we won!!! love the land!!! #allin #cavs #champ...
# 10      0   @user @user welcome here !  i'm   it's so #gr8 !

# %%
MAX_PREDOMINANT_LABEL_SAMPLES = 10000

dfNonHate = df[df["label"] == 0].head(MAX_PREDOMINANT_LABEL_SAMPLES)
dfHate = df[df["label"] == 1]

df = pd.concat([dfNonHate, dfHate])

# %% [markdown]
# ### Train & test splits

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.4, random_state=42)

print('train data length:', len(X_train))
print('test data length:', len(X_test))
# Out:
# train data length: 7345
# test data length: 4897

# %%
dfTrainTfidf = pd.DataFrame(list(zip(X_train, y_train)), columns =['text', 'label'])
dfTrainTfidf.head()

dfTrainCbow = pd.DataFrame(list(zip(X_train, y_train)), columns =['text', 'label'])
dfTrainCbow.head()
# Out:
#                                                 text  label
# 0  keeping to my happiness goals for the month - ...      0
# 1   @user as a huge @user fan i'm excited for liv...      0
# 2  ððlove girlsðð   #bihday #yuiko#pa...      0
# 3  this much #hatred, #xenophobia, #islamophobia,...      1
# 4  @user can't wait... excited to watch lemans th...      0

# %%
dfTestTfidf = pd.DataFrame(list(zip(X_test, y_test)), columns =['text', 'label'])
dfTestTfidf.head()

dfTestCbow = pd.DataFrame(list(zip(X_test, y_test)), columns =['text', 'label'])
dfTestCbow.head()
# Out:
#                                                 text  label
# 0  i worked to had for this #highschoolgraduation...      0
# 1  so proud to have a mayor like @user who isnt a...      1
# 2    #bihday #shout #out to my broda @user smile ...      0
# 3       i am wholesome. #i_am #positive #affirmation      0
# 4  #nazi #swastika #ebay! #trump #donaldtrump #re...      1

# %% [markdown]
# ### Preprocessing

# %%
def apply(df, functions):
    for f in functions:
        df = df.apply(f)
    return df

def removeHyperlinks(text):
    return re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)

def removeHandles(text):
    return re.sub(r'@[\w]*', ' ', text)

def removeHashtags(text):
    return re.sub(r'#', ' ', text)

def removeHashtagsAndWords(text):
    return re.sub(r'#[\w]*', ' ', text)

def removeRepeating(text):
    return re.sub(r'([a-zA-Z])\1{2,}', r'\1', text)

def removeWhitespaces(text):
    return re.sub(r'\s+', ' ', text)

def removeDigits(text):
    return re.sub(r'\d+', '', text)

def unidecodeLowercase(text):
    return unidecode(text.lower())

def removePunctuation(text):
    return "".join(c if c not in string.punctuation else ' ' for c in text)

def removeStopwords(text):
    return " ".join([w for w in text.split() if w.lower() not in STOP_WORDS and len(w) > 2])

def stem(text):
    return " ".join([stemmer.stem(token) for token in text.split()])

def lemma(text):
    return " ".join([w.lemma_ for w in nlp(text)])

# %%
tfIdf_preprocessing = [
    unidecodeLowercase,
    removeHyperlinks,
    removeHandles,
    removeHashtags,
    removePunctuation,
    removeDigits,
    removeRepeating,
    lemma,
    removeStopwords,
    removeWhitespaces
]

cbow_preprocessing = [
    unidecodeLowercase,
    removeHyperlinks,
    removeHandles,
    removeHashtagsAndWords,
    removePunctuation,
    removeDigits,
    removeRepeating,
    lemma,
    removeStopwords,
    removeWhitespaces
]

# %%
dfTrainTfidf['clean'] = apply(dfTrainTfidf['text'], tfIdf_preprocessing)
dfTrainTfidf['tokens'] = [text.split() for text in dfTrainTfidf['clean'].tolist()]

dfTrainTfidf.head(10)
# Out:
#                                                 text  label  \
# 0  keeping to my happiness goals for the month - ...      0
# 1   @user as a huge @user fan i'm excited for liv...      0
# 2  ððlove girlsðð   #bihday #yuiko#pa...      0
# 3  this much #hatred, #xenophobia, #islamophobia,...      1
# 4  @user can't wait... excited to watch lemans th...      0
# 5                     lol i just feel   and #useless      0
# 6    is defunding aboion and sending you to the #...      1
# 7  there are ceain happenings in our lives that w...      0
# 8    train tickets booked for my opera week in wales      0
# 9  #e3 just isn't the same without @user @user @u...      0
#
#                                                clean  \
# 0  keep happiness goal month outside get fresh ai...
# 1  huge fan excited live stream amp midday via gi...
# 2                   ddlove girlsdd bihday yuiko paya
# 3  much hatred xenophobia islamophobia antisemiti...
# 4  wait excited watch leman year lemans lemans le...
# 5                                   lol feel useless
# 6                   defunde aboion send inauguration
# 7           ceain happening life woh like agree life
# 8                  train ticket book opera week wale
# 9         without cover together gwaslife missyouguy
#
#                                               tokens
# 0  [keep, happiness, goal, month, outside, get, f...
# 1  [huge, fan, excited, live, stream, amp, midday...
# 2             [ddlove, girlsdd, bihday, yuiko, paya]
# 3  [much, hatred, xenophobia, islamophobia, antis...
# 4  [wait, excited, watch, leman, year, lemans, le...
# 5                               [lol, feel, useless]
# 6              [defunde, aboion, send, inauguration]
# 7   [ceain, happening, life, woh, like, agree, life]
# 8           [train, ticket, book, opera, week, wale]
# 9   [without, cover, together, gwaslife, missyouguy]

# %%
dfTestTfidf['clean'] = apply(dfTestTfidf['text'], tfIdf_preprocessing)
dfTestTfidf['tokens'] = [text.split() for text in dfTestTfidf['clean'].tolist()]

dfTestTfidf.head(10)
# Out:
#                                                 text  label  \
# 0  i worked to had for this #highschoolgraduation...      0
# 1  so proud to have a mayor like @user who isnt a...      1
# 2    #bihday #shout #out to my broda @user smile ...      0
# 3       i am wholesome. #i_am #positive #affirmation      0
# 4  #nazi #swastika #ebay! #trump #donaldtrump #re...      1
# 5  @user disgusting racist thugs, look forward to...      1
# 6  boummmmm cleveland ð #teamlebron  #clevelan...      0
# 7            fathers day to mine and all! #thankspop      0
# 8  @user  with all,due respect he was m.m.a.#lege...      0
# 9  @user it's laughable to see all these "celebri...      0
#
#                                                clean  \
# 0          work highschoolgraduation classof diploma
# 1  proud mayor like afraid speak truth yes comple...
# 2    bihday shout broda smile shine like star whilea
# 3                     wholesome positive affirmation
# 4  nazi swastika ebay trump donaldtrump republic ...
# 5         disgust racist thug look forward back jail
# 6  boum cleveland teamlebron cleveland nba basket...
# 7                          father day mine thankspop
# 8                  due respect legend rip kimbo loss
# 9  laughable see celebrity ali funeral funeral se...
#
#                                               tokens
# 0     [work, highschoolgraduation, classof, diploma]
# 1  [proud, mayor, like, afraid, speak, truth, yes...
# 2  [bihday, shout, broda, smile, shine, like, sta...
# 3                 [wholesome, positive, affirmation]
# 4  [nazi, swastika, ebay, trump, donaldtrump, rep...
# 5  [disgust, racist, thug, look, forward, back, j...
# 6  [boum, cleveland, teamlebron, cleveland, nba, ...
# 7                     [father, day, mine, thankspop]
# 8           [due, respect, legend, rip, kimbo, loss]
# 9  [laughable, see, celebrity, ali, funeral, fune...

# %%
dfTrainCbow['clean'] = apply(dfTrainCbow['text'], cbow_preprocessing)
dfTrainCbow['tokens'] = [text.split() for text in dfTrainCbow['clean'].tolist()]

dfTrainCbow.head(10)
# Out:
#                                                 text  label  \
# 0  keeping to my happiness goals for the month - ...      0
# 1   @user as a huge @user fan i'm excited for liv...      0
# 2  ððlove girlsðð   #bihday #yuiko#pa...      0
# 3  this much #hatred, #xenophobia, #islamophobia,...      1
# 4  @user can't wait... excited to watch lemans th...      0
# 5                     lol i just feel   and #useless      0
# 6    is defunding aboion and sending you to the #...      1
# 7  there are ceain happenings in our lives that w...      0
# 8    train tickets booked for my opera week in wales      0
# 9  #e3 just isn't the same without @user @user @u...      0
#
#                                                clean  \
# 0  keep happiness goal month outside get fresh ai...
# 1        huge fan excited live stream amp midday via
# 2                                     ddlove girlsdd
# 3                        much much let hope get less
# 4                      wait excited watch leman year
# 5                                           lol feel
# 6                                defunde aboion send
# 7                ceain happening life woh like agree
# 8                  train ticket book opera week wale
# 9                             without cover together
#
#                                               tokens
# 0  [keep, happiness, goal, month, outside, get, f...
# 1  [huge, fan, excited, live, stream, amp, midday...
# 2                                  [ddlove, girlsdd]
# 3                 [much, much, let, hope, get, less]
# 4                [wait, excited, watch, leman, year]
# 5                                        [lol, feel]
# 6                            [defunde, aboion, send]
# 7         [ceain, happening, life, woh, like, agree]
# 8           [train, ticket, book, opera, week, wale]
# 9                         [without, cover, together]

# %%
dfTestCbow['clean'] = apply(dfTestCbow['text'], cbow_preprocessing)
dfTestCbow['tokens'] = [text.split() for text in dfTestCbow['clean'].tolist()]

dfTestCbow.head(10)
# Out:
#                                                 text  label  \
# 0  i worked to had for this #highschoolgraduation...      0
# 1  so proud to have a mayor like @user who isnt a...      1
# 2    #bihday #shout #out to my broda @user smile ...      0
# 3       i am wholesome. #i_am #positive #affirmation      0
# 4  #nazi #swastika #ebay! #trump #donaldtrump #re...      1
# 5  @user disgusting racist thugs, look forward to...      1
# 6  boummmmm cleveland ð #teamlebron  #clevelan...      0
# 7            fathers day to mine and all! #thankspop      0
# 8  @user  with all,due respect he was m.m.a.#lege...      0
# 9  @user it's laughable to see all these "celebri...      0
#
#                                                clean  \
# 0                                               work
# 1  proud mayor like afraid speak truth yes comple...
# 2                 broda smile shine like star whilea
# 3                                          wholesome
# 4
# 5         disgust racist thug look forward back jail
# 6                                     boum cleveland
# 7                                    father day mine
# 8                               due respect rip loss
# 9  laughable see celebrity ali funeral funeral se...
#
#                                               tokens
# 0                                             [work]
# 1  [proud, mayor, like, afraid, speak, truth, yes...
# 2          [broda, smile, shine, like, star, whilea]
# 3                                        [wholesome]
# 4                                                 []
# 5  [disgust, racist, thug, look, forward, back, j...
# 6                                  [boum, cleveland]
# 7                                [father, day, mine]
# 8                          [due, respect, rip, loss]
# 9  [laughable, see, celebrity, ali, funeral, fune...

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# ##### Tf-idf features

# %%
tfidf = TfidfVectorizer(
    lowercase=True,
    ngram_range=(2, 8),
    max_features=None,
    analyzer='char',
    binary=True,
    strip_accents='unicode',
)

# %%
train_tfidf_features = tfidf.fit_transform(dfTrainTfidf['clean'].tolist())

feature_names = tfidf.get_feature_names_out()
feature_names
# Out:
# array([' a', ' aa', ' aae', ..., 'zzy reci', 'zzy rel', 'zzy rela'],
#       dtype=object)

# %%
test_tfidf_features = tfidf.transform(dfTestTfidf['clean'].tolist())

# %% [markdown]
# ##### Cbow features

# %%
cbow = Word2Vec(
    min_count=1,
    vector_size=1000,
    window=5,
    sg=0, # sg = 0 => CBOW
)

# %%
cbow.build_vocab(dfTrainCbow['tokens'].tolist())
cbow.train(dfTrainCbow['tokens'], total_examples=cbow.vector_size, epochs=200)

word2vec_features = cbow.wv

train_features = [
    [cbow.wv[token] if token in cbow.wv else np.zeros(cbow.vector_size) for token in row] 
    if len(row) else [np.zeros(cbow.vector_size)] for row in dfTrainCbow['tokens']]


print(len(train_features))

train_cbow_features = np.array([np.sum(features, axis=0) for features in train_features])
train_cbow_features_normalized = sklearn.preprocessing.MinMaxScaler().fit_transform(train_cbow_features)
# Out:
# 7345

# %%
test_features = [
    [cbow.wv[token] if token in cbow.wv else np.zeros(cbow.vector_size) for token in row] 
    if len(row) else [np.zeros(cbow.vector_size)] for row in dfTestCbow['tokens']]

print(len(test_features))

test_cbow_features = np.array([np.sum(features, axis=0) for features in test_features])
test_cbow_features_normalized = sklearn.preprocessing.MinMaxScaler().fit_transform(test_cbow_features)
# Out:
# 4897

# %% [markdown]
# ### Models

# %%
def print_confusion_matrix(y_true, y_pred, title):
    title += "    f1: " + "{:.2f}".format(f1_score(y_test, y_pred, average="macro"))
    matrix = confusion_matrix(y_true, y_pred)
    seaborn.heatmap(matrix, annot=True, fmt='g')
    plt.title(title)

# %% [markdown]
# ##### Multinomial Naive Bayes with Tf-Idf

# %%
mnb_tfidf = MultinomialNB()
mnb_tfidf.fit(train_tfidf_features, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = mnb_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      4021
#            1       0.99      0.12      0.22       876
#
#     accuracy                           0.84      4897
#    macro avg       0.92      0.56      0.57      4897
# weighted avg       0.87      0.84      0.79      4897

# %%
print_confusion_matrix(y_test, y_pred, "MultinomialNB Tf-Idf")

# %% [markdown]
# ##### Multinomial Naive Bayes with Normalized CBOW

# %%
mnb_cbow = MultinomialNB()
mnb_cbow.fit(train_cbow_features_normalized, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = mnb_cbow.predict(test_cbow_features_normalized)

print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      4021
#            1       0.65      0.23      0.34       876
#
#     accuracy                           0.84      4897
#    macro avg       0.75      0.60      0.62      4897
# weighted avg       0.82      0.84      0.81      4897

# %%
print_confusion_matrix(y_test, y_pred, "MultinomialNB CBOW")

# %% [markdown]
# ##### Ridge with Tf-Idf

# %%
rc_tfidf = RidgeClassifier()
rc_tfidf.fit(train_tfidf_features, y_train)
# Out:
# RidgeClassifier()

# %%
y_pred = rc_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4021
#            1       0.91      0.67      0.77       876
#
#     accuracy                           0.93      4897
#    macro avg       0.92      0.83      0.86      4897
# weighted avg       0.93      0.93      0.92      4897

# %%
print_confusion_matrix(y_test, y_pred, "Ridge Tf-Idf")

# %% [markdown]
# ##### Ridge with CBOW

# %%
rc_cbow = RidgeClassifier()
rc_cbow.fit(train_cbow_features, y_train)
# Out:
# RidgeClassifier()

# %%
y_pred = rc_cbow.predict(test_cbow_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92      4021
#            1       0.76      0.37      0.50       876
#
#     accuracy                           0.87      4897
#    macro avg       0.82      0.67      0.71      4897
# weighted avg       0.86      0.87      0.85      4897

# %%
print_confusion_matrix(y_test, y_pred, "Ridge CBOW")

# %% [markdown]
# ##### RBF SVC with Tf-Idf

# %%
svc_tfidf = SVC(kernel='rbf', C=1.1)
svc_tfidf.fit(train_tfidf_features, y_train)
# Out:
# SVC(C=1.1)

# %%
y_pred = svc_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      4021
#            1       0.93      0.56      0.70       876
#
#     accuracy                           0.91      4897
#    macro avg       0.92      0.78      0.83      4897
# weighted avg       0.92      0.91      0.91      4897

# %%
print_confusion_matrix(y_test, y_pred, "RBF SVC Tf-Idf")

# %% [markdown]
# ##### RBF SVC with CBOW

# %%
svc_cbow = SVC(kernel='rbf', C=1.1)
svc_cbow.fit(train_cbow_features, y_train)
# Out:
# SVC(C=1.1)

# %%
y_pred = svc_cbow.predict(test_cbow_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      4021
#            1       0.80      0.43      0.56       876
#
#     accuracy                           0.88      4897
#    macro avg       0.84      0.71      0.75      4897
# weighted avg       0.87      0.88      0.86      4897

# %%
print_confusion_matrix(y_test, y_pred, "RBF SVC CBOW")

# %% [markdown]
# ##### Linear SVC with Tf-Idf

# %%
lsvc_tfidf = LinearSVC(C=1.1)
lsvc_tfidf.fit(train_tfidf_features, y_train)
# Out:
# LinearSVC(C=1.1)

# %%
y_pred = lsvc_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4021
#            1       0.89      0.71      0.79       876
#
#     accuracy                           0.93      4897
#    macro avg       0.91      0.85      0.88      4897
# weighted avg       0.93      0.93      0.93      4897

# %%
print_confusion_matrix(y_test, y_pred, "Linear SVC Tf-Idf")

# %% [markdown]
# ##### Linear SVC with CBOW

# %%
lsvc_cbow = LinearSVC(max_iter=5000)
lsvc_cbow.fit(train_cbow_features, y_train)
# Out:
# C:\Users\gruia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(max_iter=5000)

# %%
y_pred = lsvc_cbow.predict(test_cbow_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93      4021
#            1       0.73      0.47      0.57       876
#
#     accuracy                           0.87      4897
#    macro avg       0.81      0.72      0.75      4897
# weighted avg       0.86      0.87      0.86      4897

# %%
print_confusion_matrix(y_test, y_pred, "Linear SVC CBOW")

# %% [markdown]
# ##### Gradient Boosting with Tf-Idf

# %%
gradient_tfidf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, subsample=0.75)
gradient_tfidf.fit(train_tfidf_features, y_train)
# Out:
# GradientBoostingClassifier(subsample=0.75)

# %%
y_pred = gradient_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4021
#            1       0.84      0.51      0.63       876
#
#     accuracy                           0.89      4897
#    macro avg       0.87      0.74      0.79      4897
# weighted avg       0.89      0.89      0.88      4897

# %%
print_confusion_matrix(y_test, y_pred, "Gradient Boosting Tf-Idf")

# %% [markdown]
# ##### Gradient Boosting with CBOW

# %%
gradient_cbow = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, subsample=0.75)
gradient_cbow.fit(train_cbow_features, y_train)
# Out:
# GradientBoostingClassifier(subsample=0.75)

# %%
y_pred = gradient_cbow.predict(test_cbow_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      4021
#            1       0.75      0.48      0.58       876
#
#     accuracy                           0.88      4897
#    macro avg       0.82      0.72      0.76      4897
# weighted avg       0.87      0.88      0.87      4897

# %%
print_confusion_matrix(y_test, y_pred, "Gradient Boosting CBOW")

# %% [markdown]
# ##### Neural Network with Tf-Idf

# %%
neural_tfidf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(100,), random_state=0, max_iter=500)
neural_tfidf.fit(train_tfidf_features, y_train)
# Out:
# MLPClassifier(alpha=1e-05, max_iter=500, random_state=0, solver='lbfgs')

# %%
y_pred = neural_tfidf.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4021
#            1       0.83      0.76      0.80       876
#
#     accuracy                           0.93      4897
#    macro avg       0.89      0.86      0.88      4897
# weighted avg       0.93      0.93      0.93      4897

# %%
print_confusion_matrix(y_test, y_pred, "Neural Network Tfidf")

# %% [markdown]
# ##### Neural Network with CBOW

# %%
neural_cbow = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(100,), random_state=0, max_iter=5000)
neural_cbow.fit(train_cbow_features, y_train)
# Out:
# MLPClassifier(alpha=1e-05, max_iter=5000, random_state=0, solver='lbfgs')

# %%
y_pred = neural_cbow.predict(test_cbow_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4021
#            1       0.55      0.61      0.58       876
#
#     accuracy                           0.84      4897
#    macro avg       0.73      0.75      0.74      4897
# weighted avg       0.85      0.84      0.85      4897

# %%
print_confusion_matrix(y_test, y_pred, "Neural Network Cbow")

# %% [markdown]
# ##### XGBoost with Tf-Idf

# %%
xgboost = XGBClassifier(learning_rate=0.15, gamma=0.5, reg_alpha=0.5, max_depth=10, subsample=0.8, colsample_bytree=0.75, n_estimators=475)
xgboost.fit(train_tfidf_features, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.75, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=475, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred = xgboost.predict(test_tfidf_features)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      4021
#            1       0.83      0.64      0.73       876
#
#     accuracy                           0.91      4897
#    macro avg       0.88      0.81      0.84      4897
# weighted avg       0.91      0.91      0.91      4897

# %%
print_confusion_matrix(y_test, y_pred, "XGBoost Tf-Idf")

# %% [markdown]
# ##### Pre-trained Models - Model 1

# %%
# source: https://huggingface.co/patrickquick/BERTicelli?text=Keep+up+the+good+hard+work.

tokenizer1 = AutoTokenizer.from_pretrained("patrickquick/BERTicelli")
model1 = AutoModelForSequenceClassification.from_pretrained("patrickquick/BERTicelli")
classifier1 = pipeline("text-classification", model=model1, tokenizer=tokenizer1)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 361/361 [00:00<00:00, 355kB/s]
# C:\Users\gruia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\gruia\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 213k/213k [00:00<00:00, 858kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 112/112 [00:00<00:00, 112kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 792/792 [00:00<00:00, 396kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 433M/433M [00:37<00:00, 11.7MB/s]

# %%
y_pred = [0 if classifier1(sentence)[0]['label'] == 'NOT' else 1 for sentence in dfTestTfidf['text']]

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.89      4021
#            1       0.43      0.26      0.32       876
#
#     accuracy                           0.80      4897
#    macro avg       0.64      0.59      0.60      4897
# weighted avg       0.78      0.80      0.79      4897

# %%
print_confusion_matrix(y_test, y_pred, "First pretrained model")

# %% [markdown]
# ##### Pre-trained Models - Model 2

# %%
# source: https://huggingface.co/MilaNLProc/bert-base-uncased-ear-mlma

tokenizer2 = AutoTokenizer.from_pretrained("MilaNLProc/bert-base-uncased-ear-mlma")
model2 = AutoModelForSequenceClassification.from_pretrained("MilaNLProc/bert-base-uncased-ear-mlma")
classifier2 = pipeline("text-classification", model=model2, tokenizer=tokenizer2)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 348/348 [00:00<00:00, 689kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 1.72MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 711k/711k [00:00<00:00, 1.43MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 125/125 [00:00<00:00, 125kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 802/802 [00:00<00:00, 804kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 438M/438M [00:37<00:00, 11.6MB/s]

# %%
y_pred = [0 if classifier2(sentence)[0]['label'] == 'non-hateful' else 1 for sentence in dfTestTfidf['text']]

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.49      0.63      4021
#            1       0.25      0.77      0.37       876
#
#     accuracy                           0.54      4897
#    macro avg       0.58      0.63      0.50      4897
# weighted avg       0.79      0.54      0.59      4897

# %%
print_confusion_matrix(y_test, y_pred, "Second pretrained model")

# %% [markdown]
# ##### Pre-trained Models - Model 3

# %%
# source: https://huggingface.co/facebook/roberta-hate-speech-dynabench-r4-target

tokenizer3 = AutoTokenizer.from_pretrained("facebook/roberta-hate-speech-dynabench-r4-target")
model3 = AutoModelForSequenceClassification.from_pretrained("facebook/roberta-hate-speech-dynabench-r4-target")
classifier3 = pipeline("text-classification", model=model3, tokenizer=tokenizer3)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 1.11k/1.11k [00:00<00:00, 1.11MB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 899k/899k [00:00<00:00, 1.76MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 1.21MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 239/239 [00:00<00:00, 239kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 816/816 [00:00<00:00, 811kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 499M/499M [00:42<00:00, 11.7MB/s]

# %%
y_pred = [0 if classifier3(sentence)[0]['label'] == 'nothate' else 1 for sentence in dfTestTfidf['text']]

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      4021
#            1       0.53      0.19      0.28       876
#
#     accuracy                           0.82      4897
#    macro avg       0.69      0.58      0.59      4897
# weighted avg       0.79      0.82      0.79      4897

# %%
print_confusion_matrix(y_test, y_pred, "Third pretrained model")

# %% [markdown]
# ##### Pre-trained Models - Model 4

# %%
# source: https://huggingface.co/Hate-speech-CNERG/bert-base-uncased-hatexplain

tokenizer4 = AutoTokenizer.from_pretrained("Hate-speech-CNERG/bert-base-uncased-hatexplain")
model4 = AutoModelForSequenceClassification.from_pretrained("Hate-speech-CNERG/bert-base-uncased-hatexplain")
classifier4 = pipeline("text-classification", model=model4, tokenizer=tokenizer4)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 40.0/40.0 [00:00<00:00, 40.0kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 1.08k/1.08k [00:00<00:00, 1.08MB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 899kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 112/112 [00:00<00:00, 112kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 438M/438M [00:37<00:00, 11.7MB/s]

# %%
y_pred = [0 if classifier4(sentence)[0]['label'] == 'normal' else 1 for sentence in dfTestTfidf['text']]

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      4021
#            1       0.51      0.07      0.13       876
#
#     accuracy                           0.82      4897
#    macro avg       0.67      0.53      0.51      4897
# weighted avg       0.77      0.82      0.76      4897

# %%
print_confusion_matrix(y_test, y_pred, "Fourth pretrained model")

# %% [markdown]
# ##### Pre-trained Models - Model 5

# %%
# source: https://huggingface.co/Hate-speech-CNERG/dehatebert-mono-english

tokenizer5 = AutoTokenizer.from_pretrained("Hate-speech-CNERG/dehatebert-mono-english")
model5 = AutoModelForSequenceClassification.from_pretrained("Hate-speech-CNERG/dehatebert-mono-english")
classifier5 = pipeline("text-classification", model=model5, tokenizer=tokenizer5)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 152/152 [00:00<00:00, 75.9kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 1.23k/1.23k [00:00<00:00, 1.23MB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 872k/872k [00:00<00:00, 1.72MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 112/112 [00:00<00:00, 55.8kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 669M/669M [00:57<00:00, 11.5MB/s]

# %%
y_pred = [0 if classifier5(sentence)[0]['label'] == 'NON_HATE' else 1 for sentence in dfTestTfidf['text']]

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      4021
#            1       0.34      0.38      0.36       876
#
#     accuracy                           0.76      4897
#    macro avg       0.60      0.61      0.60      4897
# weighted avg       0.77      0.76      0.76      4897

# %%
print_confusion_matrix(y_test, y_pred, "Fifth pretrained model")

# %% [markdown]
# #### Deep Neural Network

# %%
train_tokens = dfTrainTfidf['tokens']

# Create the Word2Vec model
model = Word2Vec(vector_size=300, window=2, min_count=3, workers=8, sg=1)

# # Build the vocabulary
model.build_vocab(train_tokens)
# # Train the Word2Vec model

model.train(train_tokens, total_examples=model.corpus_count, epochs=40)
# Out:
# (1604019, 2219680)

# %%
def preprocess(review):
  representation = np.zeros(300)
  n_words = 0
  for word in review:
    try:
      representation += model.wv[word]
      n_words += 1
    except:
      pass

  if n_words == 0:
    return representation

  return representation / n_words

# %%
train_data = np.array([preprocess(dfTrainTfidf.iloc[[i]]['tokens'].tolist()[0]) for i in range(dfTrainTfidf['clean'].size)]).astype(np.float32)
test_data = np.array([preprocess(dfTestTfidf.iloc[[i]]['tokens'].tolist()[0]) for i in range(dfTestTfidf['clean'].size)]).astype(np.float32)

# %%
train_labels = dfTrainTfidf['label']
test_labels = dfTestTfidf['label']

train_data
# Out:
# array([[ 0.05244909,  0.07699322, -0.18659525, ..., -0.06171143,
#          0.04325939, -0.07935431],
#        [ 0.14762884,  0.38687864, -0.06588931, ..., -0.2142567 ,
#          0.18529727, -0.13131414],
#        [ 0.15652446,  0.67709243, -0.31990787, ...,  0.19326533,
#          0.4625048 , -0.4372252 ],
#        ...,
#        [-0.08260119,  0.16176909, -0.00882446, ..., -0.07936489,
#          0.17000768, -0.10540859],
#        [ 0.16059709,  0.19192679,  0.33348554, ...,  0.02103947,
#          0.27435184, -0.02897263],
#        [ 0.04845651,  0.10834374, -0.06549765, ..., -0.16540597,
#          0.2017819 , -0.11375146]], dtype=float32)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
        self.layer = torch.nn.Sequential(
            torch.nn.Linear(300, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 2)
        )
    
    def forward(self, input):
        return self.layer(input)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, split):
        super().__init__()
        
        if split == 'train':
            self.data = train_data
            self.labels = train_labels
        else:
            self.data = test_data
            self.labels = test_labels
        
    def __getitem__(self, sample_n):
        return self.data[sample_n], self.labels[sample_n]
    
    def __len__(self):
        return len(self.labels)

# %%
model = Model()
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

batch_size = 256
train_dataset = Dataset(split = 'train')
train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    shuffle = True,
    batch_size = batch_size,
    num_workers = 10,
)
val_dataset = Dataset(split = 'test')
val_dataloader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size = batch_size,
    num_workers = 10,
)

predictions = []
best_acc = 0

# %%
for epoch_n in tqdm(range(100)):
    model.train()
    for batch in train_dataloader:
        input, target = batch
        input = input
        target = target
        
        optimizer.zero_grad()

        output = model(input)
        loss = loss_function(output, target)

        loss.backward()
        optimizer.step()
        
    model.eval()
    current_predictions = []
    val_acc = []

    for batch in val_dataloader:
        input, target = batch
        input = input
        target = target
        
        with torch.no_grad():
            output = model(input)
            current_predictions.extend(output.argmax(1))
        
        val_acc += (output.argmax(1) == target).tolist()
    
    acc = np.mean(val_acc)
    if(acc > best_acc):
      torch.save(model.state_dict(), "sample_data/best_model.pt")
      best_acc = acc
      predictions = current_predictions

    print(acc)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
model.load_state_dict(torch.load("sample_data/best_model.pt"))

# %%
predictions = []

for batch in val_dataloader:
        input, target = batch
        input = input
        target = target
        
        with torch.no_grad():
            output = model(input)
            predictions.extend(output.argmax(1))

predictions = [int(x) for x in predictions]
print(predictions)

# %%
print(classification_report(y_test, predictions, zero_division=0))

# %%
print_confusion_matrix(y_test, predictions, "Deep learning")
